# %% [markdown]
# <a href="https://colab.research.google.com/github/nguyenanhtienabcd/M01_PROJECT_YOLOv10_OBJECT_DETECTION/blob/feature%2FYOLOv10-object-detection/MODULE1_Project_YOLOv10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 1. Load file to COLAB

# %%
# !git clone https://github.com/THU-MIG/yolov10.git
# Out:
# Cloning into 'yolov10'...
# remote: Enumerating objects: 20304, done.
# remote: Counting objects: 100% (1347/1347), done.
# remote: Compressing objects: 100% (127/127), done.
# remote: Total 20304 (delta 1301), reused 1223 (delta 1220), pack-reused 18957
# Receiving objects: 100% (20304/20304), 11.18 MiB | 14.94 MiB/s, done.
# Resolving deltas: 100% (14304/14304), done.

# %% [markdown]
# ## 2. install necessary libraries

# %%
# %cd yolov10
# !pip install -q -r requirements.txt
# !pip install -e.
# Out:
# /content/yolov10/yolov10
# Obtaining file:///content/yolov10/yolov10
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Building editable for ultralytics (pyproject.toml) ... done
#   Created wheel for ultralytics: filename=ultralytics-8.1.34-0.editable-py3-none-any.whl size=20531 sha256=ac2a5c001b74555281c16bd2774123e93b1557bc78152e4540c081094cda54f0
#   Stored in directory: /tmp/pip-ephem-wheel-cache-y6p8j02e/wheels/1b/af/1f/f1aee6481cd8edfbf40edb1962f9ce637ca946fc28610f9af3
# Successfully built ultralytics
# ...
#   Attempting uninstall: ultralytics
#     Found existing installation: ultralytics 8.1.34
#     Uninstalling ultralytics-8.1.34:
#       Successfully uninstalled ultralytics-8.1.34
# ...

# %% [markdown]
# ## 3. Download yolo10n type

# %%
# !wget wget https://github.com/THU-MIG/yolov10/releases/download/v1.1/yolov10n.pt

# %% [markdown]
# ## 4. Download dataset

# %%
# !gdown 1twdtZEfcw4ghSZIiPDypJurZnNXzMO7R
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1twdtZEfcw4ghSZIiPDypJurZnNXzMO7R
# From (redirected): https://drive.google.com/uc?id=1twdtZEfcw4ghSZIiPDypJurZnNXzMO7R&confirm=t&uuid=d102f082-17e9-4c00-9109-ce63e7618f93
# To: /content/yolov10/Safety_Helmet_Dataset.zip
# 100% 33.7M/33.7M [00:00<00:00, 33.9MB/s]

# %%
# !mkdir safety_helmet_dataset
# !unzip /content/yolov10/Safety_Helmet_Dataset.zip -d safety_helmet_dataset
# Out:
# Archive:  /content/yolov10/Safety_Helmet_Dataset.zip
#  extracting: safety_helmet_dataset/README.dataset.txt
#  extracting: safety_helmet_dataset/README.roboflow.txt
#  extracting: safety_helmet_dataset/data.yaml
#    creating: safety_helmet_dataset/test/
#    creating: safety_helmet_dataset/test/images/
#  extracting: safety_helmet_dataset/test/images/helmet-10-_jpg.rf.eee985865a1a52407316f0c9ea7a9b3e.jpg
#  extracting: safety_helmet_dataset/test/images/helmet-108-_jpg.rf.85e7ccb9c8c26013fe9016001b68fc72.jpg
#  extracting: safety_helmet_dataset/test/images/helmet-110-_jpg.rf.b9d38442adb18ac5188cee9ef27392d5.jpg
#  extracting: safety_helmet_dataset/test/images/helmet-12-_jpg.rf.e060b7cfb30b033ca50fc1b9ed48efe7.jpg
#  extracting: safety_helmet_dataset/test/images/helmet-135-_jpg.rf.d94276d795b6dc4edc5b3caa89b73b8a.jpg
#  extracting: safety_helmet_dataset/test/images/helmet-136-_jpg.rf.167f996a6fc4e10c7884f5b3e7e65be3.jpg
# ...

# %% [markdown]
# ## 6. Training

# %%
#import torch
#torch.cuda.empty_cache()
from ultralytics import YOLOv10
MODEL_PATH = '/content/yolov10/yolov10n.pt'
model = YOLOv10(MODEL_PATH)

# %%
YALM_PATH = '/content/yolov10/safety_helmet_dataset/data.yaml'
EPORCH  = 50
IMG_SIZE = 640
BATCH_SIZE = 64
model.train(
    data=YALM_PATH,
    epochs=EPORCH,
    imgsz=IMG_SIZE,
    batch=BATCH_SIZE)
# Out:
# New https://pypi.org/project/ultralytics/8.2.48 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.1.34 🚀 Python-3.10.12 torch-2.0.1+cu117 CPU (Intel Xeon 2.20GHz)
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 7. Evaluate

# %%
from ultralytics import YOLOv10
TRAINED_MODEL_PATH = '/content/yolov10/runs/detect/train/weights/best.pt'
YAML_PATH = '/content/yolov10/safety_helmet_dataset/data.yaml'
IMG_SIZE = 400
model = YOLOv10(TRAINED_MODEL_PATH)

model.val(data=YAML_PATH,
          imgsz=IMG_SIZE,
          split='test')
# Out:
# WARNING ⚠️ imgsz=[400] must be multiple of max stride 32, updating to [416]
# Ultralytics YOLOv8.1.34 🚀 Python-3.10.12 torch-2.0.1+cu117 CPU (Intel Xeon 2.20GHz)
# YOLOv10n summary (fused): 285 layers, 2695586 parameters, 0 gradients, 8.2 GFLOPs
# val: Scanning /content/yolov10/safety_helmet_dataset/test/labels.cache... 109 images, 0 backgrounds, 0 corrupt: 100%|██████████| 109/109 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:18<00:00,  2.60s/it]
#                    all        109        320      0.721      0.771      0.801      0.436
#                   head        109         16      0.813      0.625      0.767       0.39
#                 helmet        109        162      0.711      0.864      0.884      0.476
#                 person        109        142      0.639      0.824      0.753      0.443
# Speed: 1.4ms preprocess, 155.0ms inference, 0.0ms loss, 0.2ms postprocess per image
# ...

# %% [markdown]
# ## 8. Predict

# %%
from google.colab.patches import cv2_imshow

IMAGE_URL = 'https://d3uwoey2rd901c.cloudfront.net/wp-content/uploads/2018/06/Rice-Media-construction-worker-helmets-colours-occupation.jpg'
CONF_THRESHOLD = 0.3
results = model.predict(source=IMAGE_URL,
                       imgsz=IMG_SIZE,
                       conf=CONF_THRESHOLD)
annotated_img = results[0].plot()

cv2_imshow(annotated_img)
# Out:
# WARNING ⚠️ imgsz=[400] must be multiple of max stride 32, updating to [416]
# Found https://d3uwoey2rd901c.cloudfront.net/wp-content/uploads/2018/06/Rice-Media-construction-worker-helmets-colours-occupation.jpg locally at Rice-Media-construction-worker-helmets-colours-occupation.jpg
# image 1/1 /content/yolov10/yolov10/Rice-Media-construction-worker-helmets-colours-occupation.jpg: 352x416 8 helmets, 4 persons, 135.5ms
# Speed: 3.1ms preprocess, 135.5ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 416)
# <PIL.Image.Image image mode=RGB size=1436x1141>
